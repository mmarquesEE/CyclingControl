# %%
import Km3P_control as km3p
from Km3P_control import reg
km = km3p.km3(serial_port ='COM8', decimal=1)
# a = km.read(reg(652))
# b = km.read(reg(651))
km.set_temperature(50)
while(True):
     print(km.read(reg(4, dp=2)))
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[14], line 3
#       1 import Km3P_control as km3p
#       2 from Km3P_control import reg
# ----> 3 km = km3p.km3(serial_port ='COM8', decimal=1)
#       4 # a = km.read(reg(652))
#       5 # b = km.read(reg(651))
#       6 km.set_temperature(50)
#
# File c:\Users\eRobotica-01\Documents\CNPq Baterias\CyclingControl-1\km3p\Km_py_test\Km3P_control.py:47, in __init__(self, slave_address, serial_port, timeout, baud_rate, decimal, debug)
#      46 def __init__(self,slave_address=1,serial_port='/dev/ttyUSB0', timeout=0.25,baud_rate=9600, decimal=0,debug=False): #init
# ---> 47     self.km3p = minimalmodbus.Instrument(serial_port, slave_address, debug=debug)
#      48     self.km3p.serial.baudrate = baud_rate
#      49     self.km3p.serial.timeout = timeout
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\serial\serialutil.py:299, in SerialBase.baudrate(self, baudrate)
#     297 self._baudrate = b
#     298 if self.is_open:
# --> 299     self._reconfigure_port()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\serial\serialwin32.py:222, in Serial._reconfigure_port(self)
#     219 comDCB.XoffChar = serial.XOFF
#     221 if not win32.SetCommState(self._port_handle, ctypes.byref(comDCB)):
# --> 222     raise SerialException(
#     223         'Cannot configure port, something went wrong. '
#     224         'Original message: {!r}'.format(ctypes.WinError()))
#
# SerialException: Cannot configure port, something went wrong. Original message: PermissionError(13, 'Acesso negado.', None, 5)

# %%
import matplotlib.pyplot as plt
 
# line 1 points
x1 = [1,2,3]
y1 = [2,4,1]
# plotting the line 1 points 
plt.plot(x1, y1, label = "line 1")
 
# line 2 points
x2 = [1,2,3]
y2 = [4,1,3]
# plotting the line 2 points 
plt.plot(x2, y2, label = "line 2")
 
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
# giving a title to my graph
plt.title('Two lines on same graph!')
 
# show a legend on the plot
plt.legend()
 
# function to show the plot
plt.show()
