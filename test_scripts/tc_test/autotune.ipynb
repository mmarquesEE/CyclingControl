# %%
import Km3P_control as km
import time
import matplotlib.pyplot as plot

instrumento = km.km3(serial_port='COM8', decimal=1)

plot.ion()

temp = instrumento.temperature()
pot = instrumento.get_power()
sp = 0
instrumento.set_temperature(sp)
y_temp = [temp]
x_time = [0]
y_pot = [pot]
y_set = [sp]


temperatura = plot.plot(x_time, y_temp, label='temperatura')[0]
potencia = plot.plot(x_time, y_pot, label='potencia')[0]
setpoint = plot.plot(y_set, x_time, label='SetPoint')[0]
plot.ylim(max(y_temp)+1)
plot.pause(1)

plot.show()
i = 0
while True:
    i += 1
    y_temp.append(instrumento.temperature())
    y_pot.append(instrumento.get_power())
    y_set.append(sp)
    x_time.append(i)
    temperatura.remove()
    temperatura = plot.plot(x_time, y_temp, label='temperatura')[0]
    potencia = plot.plot(x_time, y_pot, label='potencia')[0]
    setpoint = plot.plot(y_set, x_time, label='SetPoint')[0]
    plot.ylim(max(y_temp))
    plot.xlim(i+5)
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 30
#      28 i += 1
#      29 y_temp.append(instrumento.temperature())
# ---> 30 y_pot.append(instrumento.get_power())
#      31 y_set.append(sp)
#      32 x_time.append(i)
#
# File c:\Users\eRobotica-01\Documents\CNPq Baterias\CyclingControl-1\km3p\Km_py_test\Km3P_control.py:66, in km3.get_power(self)
#      65 def get_power(self):
# ---> 66     return self.read(self.potency)
#
# File c:\Users\eRobotica-01\Documents\CNPq Baterias\CyclingControl-1\km3p\Km_py_test\Km3P_control.py:63, in km3.read(self, reg)
#      61 def read(self, reg:reg): #lê registrador, função fundamental
#      62     #modbus function 3 = read n registers
# ---> 63     return self.km3p.read_register(reg.address, reg.dec_point, 3, reg.singed)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\minimalmodbus.py:484, in Instrument.read_register(self, registeraddress, number_of_decimals, functioncode, signed)
#     477 _check_int(
#     478     number_of_decimals,
#     479     minvalue=0,
#     480     maxvalue=_MAX_NUMBER_OF_DECIMALS,
#     481     description="number of decimals",
#     482 )
#     483 _check_bool(signed, description="signed")
# --> 484 returnvalue = self._generic_command(
#     485     functioncode,
#     486     registeraddress,
#     487     number_of_decimals=number_of_decimals,
#     488     number_of_registers=1,
#     489     signed=signed,
#     490     payloadformat=_Payloadformat.REGISTER,
#     491 )
#     492 if int(returnvalue) == returnvalue:
#     493     return int(returnvalue)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\minimalmodbus.py:1276, in Instrument._generic_command(self, functioncode, registeraddress, value, number_of_decimals, number_of_registers, number_of_bits, signed, byteorder, payloadformat)
#    1263 payload_to_slave = _create_payload(
#    1264     functioncode,
#    1265     registeraddress,
#    (...)
#    1272     payloadformat,
#    1273 )
#    1275 # Communicate with instrument
# -> 1276 payload_from_slave = self._perform_command(functioncode, payload_to_slave)
#    1278 # There is no response for broadcasts
#    1279 if self.address == _SLAVEADDRESS_BROADCAST:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\minimalmodbus.py:1353, in Instrument._perform_command(self, functioncode, payload_to_slave)
#    1346             self._print_debug(
#    1347                 template.format(
#    1348                     self.mode, number_of_bytes_to_read, request_bytes
#    1349                 )
#    1350             )
#    1352 # Communicate
# -> 1353 response_bytes = self._communicate(request_bytes, number_of_bytes_to_read)
#    1355 if number_of_bytes_to_read == 0:
#    1356     return b""
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\minimalmodbus.py:1491, in Instrument._communicate(self, request, number_of_bytes_to_read)
#    1489 # Read response
#    1490 if number_of_bytes_to_read > 0:
# -> 1491     answer = self.serial.read(number_of_bytes_to_read)
#    1492 else:
#    1493     answer = b""
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\serial\serialwin32.py:288, in Serial.read(self, size)
#     286 if not read_ok and win32.GetLastError() not in (win32.ERROR_SUCCESS, win32.ERROR_IO_PENDING):
#     287     raise SerialException("ReadFile failed ({!r})".format(ctypes.WinError()))
# --> 288 result_ok = win32.GetOverlappedResult(
#     289     self._port_handle,
#     290     ctypes.byref(self._overlapped_read),
#     291     ctypes.byref(rc),
#     292     True)
#     293 if not result_ok:
#     294     if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
#
# KeyboardInterrupt:
